# %%
import numpy as np
import nipy
import matplotlib.pyplot as plt
import matplotlib.animation as animation

# %matplotlib inline
# %matplotlib nbagg

# %%
def input_files(data_path):
    img = nipy.load_image(data_path)
    data = img.get_data()
    
    return img, data

# %% [markdown]
# ## import NIfTI file

# %%
data_path = "../nii_file.nii"
#(x,y,z,t) of 4D-NIfTI files
img, data = input_files(data_path)

# %% [markdown]
# ## Check NIfTI coordinate and data shape

# %%
coor = img.coordmap
coor
# Out:
# AffineTransform(
#    function_domain=CoordinateSystem(coord_names=('i', 'j', 'k', 't'), name='voxels', coord_dtype=float64),
#    function_range=CoordinateSystem(coord_names=('aligned-x=L->R', 'aligned-y=P->A', 'aligned-z=I->S', 't'), name='aligned', coord_dtype=float64),
#    affine=array([[-2.00000000e+00,  6.71471565e-19,  9.08102451e-18,
#                    0.00000000e+00,  1.17855103e+02],
#                  [-6.71471565e-19,  1.97371149e+00, -3.55528235e-01,
#                    0.00000000e+00, -3.57229424e+01],
#                  [ 8.25548089e-18,  3.23207617e-01,  2.17108178e+00,
#                    0.00000000e+00, -7.24879837e+00],
#                  [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#                    1.00000000e+00,  0.00000000e+00],
#                  [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#                    0.00000000e+00,  1.00000000e+00]])
# )

# %%
data.shape
# Out:
# (128, 96, 24, 2)

# %% [markdown]
# ## Create Brain Image Animation!!

# %% [markdown]
# ### first Axial Animation

# %%
fig = plt.figure()
ims = []

for i in range(data.shape[2]):
    im = plt.imshow(data[:, :, i, 1].T, cmap='gray', animated=True)
    plt.gca().invert_yaxis()
    ims.append([im])
ani = animation.ArtistAnimation(fig, ims, interval=100)
ani.save('picture/Axial.gif' ,writer = 'imagemagick')
# Out:
# <img src="data:image/png;base64,..." width="432">
# MovieWriter imagemagick unavailable; trying to use <class 'matplotlib.animation.PillowWriter'> instead.

# %% [markdown]
# ### Next Saggital

# %%
fig = plt.figure()
ims = []

for i in range(data.shape[0]):
    im = plt.imshow(data[i, :, : , 1].T, cmap='gray', animated=True)
    plt.gca().invert_yaxis()
    ims.append([im])
ani = animation.ArtistAnimation(fig, ims, interval=100)
ani.save('picture/Saggital.gif' ,writer = 'imagemagick')
# Out:
# <img src="data:image/png;base64,..." width="432">
# MovieWriter imagemagick unavailable; trying to use <class 'matplotlib.animation.PillowWriter'> instead.

# %% [markdown]
# ### Finaly Coronal Animation

# %%
fig = plt.figure()
ims = []

for i in range(data.shape[1]):
    im = plt.imshow(data[:, i, : , 1].T, cmap='gray', animated=True)
    plt.gca().invert_yaxis()
    ims.append([im])
ani = animation.ArtistAnimation(fig, ims, interval=100)
ani.save('picture/Coronal.gif' ,writer = 'imagemagick')
# Out:
# <img src="data:image/png;base64,..." width="432">
# MovieWriter imagemagick unavailable; trying to use <class 'matplotlib.animation.PillowWriter'> instead.
